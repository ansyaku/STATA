# %% [markdown]
# Di dalam regresi time series kita sering kali menggunakan lag operator bisa berupa
# * Lag
# * Forward
# * Diffrence
# * Seasonal

# %%
Deklarasikan bahwa data yang sedang digunakan adalah data time series, berikut jenis timeseriesnya.

# %%
# . list in 1/5

#      +----------------------------------------------------+
#      | Observ~n      GDP      M2    GPDI   FEDEXP     TB6 |
#      |----------------------------------------------------|
#   1. |     1970   3771.9   626.5   427.1    201.1   6.562 |
#   2. |     1971   3898.6   710.3   475.7      220   4.511 |
#   3. |     1972     4105   802.3   532.1    244.4   4.466 |
#   4. |     1973   4341.5   855.5   594.4    261.7   7.178 |
#   5. |     1974   4319.6   902.1   550.6    293.3   7.926 |
#      +----------------------------------------------------+

# . destring Observation, replace force
# Observation: all characters numeric; replaced as int

# . describe

# Contains data from D:\OneDrive - Universitas Terbuka\00 LABORATORIUM\01. Ekonometrika\Gujarati5e\Table20_2.dta
#   obs:            36                          
#  vars:             6                          3 Jul 2021 04:15
# --------------------------------------------------------------------------------------------------------------------------------------
#               storage   display    value
# variable name   type    format     label      variable label
# --------------------------------------------------------------------------------------------------------------------------------------
# Observation     int     %10.0g                Observation
# GDP             double  %10.0g                GDP
# M2              double  %10.0g                M2
# GPDI            double  %10.0g                GPDI
# FEDEXP          double  %10.0g                FEDEXP
# TB6             double  %10.0g                TB6
# --------------------------------------------------------------------------------------------------------------------------------------
# Sorted by: 
#      Note: Dataset has changed since last saved.

# . tset Observation
#         time variable:  Observation, 1970 to 2005
#                 delta:  1 unit

# %%
# . gen quarter = quarterly(PERIOD, "YQ")

# . 
# . format quarter %tq

# . describe

# Contains data from D:\OneDrive - Universitas Terbuka\00 LABORATORIUM\01. Ekonometrika\Gujarati5e\Table21_1.dta
#   obs:           244                          
#  vars:             7                          3 Jul 2021 04:47
# --------------------------------------------------------------------------------------------------------------------------------------
#               storage   display    value
# variable name   type    format     label      variable label
# --------------------------------------------------------------------------------------------------------------------------------------
# PERIOD          str6    %9s                   PERIOD
# DPI             double  %10.0g                DPI
# GDP             double  %10.0g                GDP
# PCE             double  %10.0g                PCE
# CP              double  %10.0g                CP
# DIVIDEND        double  %10.0g                DIVIDEND
# quarter         float   %tq                   
# --------------------------------------------------------------------------------------------------------------------------------------
# Sorted by: 
#      Note: Dataset has changed since last saved.

# . list in 1/5

#      +-----------------------------------------------------------------+
#      | PERIOD      DPI        GDP      PCE     CP   DIVIDEND   quarter |
#      |-----------------------------------------------------------------|
#   1. | 1947q1     1096   1570.519   1017.2   21.2          6    1947q1 |
#   2. | 1947q2   1072.8   1568.653     1034     20        6.3    1947q2 |
#   3. | 1947q3   1102.8   1567.966   1037.5   19.8        6.5    1947q3 |
#   4. | 1947q4   1089.7   1590.938   1037.7   21.7        6.4    1947q4 |
#   5. | 1948q1   1107.3   1616.069   1042.6   22.9          7    1948q1 |
#      +-----------------------------------------------------------------+

# %% [markdown]
# ## Stochastic processes
# A random or stochastic process is a collection of random variables ordered in time.
# * If we let Y denote a random variable, and if it is continuous, we denote it as $Y(t)$
# * If we let Y denote a random variable, and if it is discrete, we denoted it as $Y_t$.
#
# ## Stationarity processes
# A stochastic process is said to be stationary if
# * its mean and variance are constant over time and
# * the value of the covariance between the two time periods depends only on the distance or gap or lag between the two time periods
# and not the actual time at which the covariance is computed.
#
# In the time series literature, such a stochastic process is known as a
# * weakly stationary, or
# * covariance stationary, or
# * second-order stationary
#
# ## Purely random processes
# We call a stochastic process purely random if it has zero mean, constant variance, and is serially uncorrelated.
# You may recall that the error term $u_t$, entering the classical normal linear regression model was assumed to be a white noise process, which we denoted as $ut ∼ IIDN(0, σ 2)$; that is, $u_t$ is independently and identically distributed as a normal distribution with zero mean and constant variance. Such a process is called a Gaussian white
# noise process.
#
# ## Nonstationary processes
# Although our interest is in stationary time series, one often encounters nonstationary time series, the classic example being the random walk model (RWM). We distinguish two types of random walks:
# * (1) random walk without drift (i.e., no constant or intercept term) and
# * (2) random walk with drift (i.e., a constant term is present).
#
# ## Integrated variables
# ## Random walk models
# ## Cointegration
# ## Deterministic and stochastic trends
# ## Unit root tests
